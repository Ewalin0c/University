# %% [markdown]
# <a href="https://colab.research.google.com/github/Ewalin0c/University/blob/main/Tasks/Module_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Задание 1
text = input("Введите текст: ")
n = text.count(" ")
print(n + 1)
# Out:
# Введите текст: В этом тексте пять слов
# 5

# %%
# Задание 2
text = input("Введите 2 слова: ")
w1, w2 = text.split()
print(w2, w1)
# Out:
# Введите 2 слова: Привет мир
# мир Привет

# %%
# Задание 3
text = input("Введите текст: ")
first = text.find('f')
last = text.rfind('f')
if first == -1:
  print(-1)
elif first == last:
  print(first)
else:
  print(first, last)
# Out:
# Введите текст: homework
# -1

# %%
# Задание 4
text = input("Введите текст: ")
new_text = text.replace("1", "one")
print(new_text)
# Out:
# Введите текст: 1+1=2
# one+one=2
